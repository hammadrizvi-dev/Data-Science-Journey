# %% [markdown]
# ### Exercise

# %%
import numpy as np

# %%
#### Valid Sudoko

# %%
sudoku = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
b= np.sum(sudoku, axis=1)
for i in b:
    if i != 45:
        print("sudoku is not valid")
        break
else:
        print("for rows it is valid")
# Out:
# for rows it is valid

# %%
c = np.sum(sudoku, axis  = 0)
for i in c:
    if i != 45:
        print("sudoku is not valid")
        break
else:
        print("for columns it is valid")
# Out:
# for columns it is valid

# %%
sudoku[0:3,0:3]
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
sudoku[0:3,3:6]
# Out:
# array([[6, 7, 8],
#        [1, 9, 5],
#        [3, 4, 2]])

# %%
sudoku[0:3,6:9]
# Out:
# array([[9, 1, 2],
#        [3, 4, 8],
#        [5, 6, 7]])

# %%
for rows in range(0,9,3):
    for columns in range(0,9,3):
        n=sudoku[rows:rows+3,columns:columns+3]
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %%
#  Columns : (Age , Maths Marks, Science Marks )
# Students
data = np.array([
    [18, 85, 78],
    [19, 92, 88],
    [17, 76, 95],
    [18, 65, 70],
    [20, 90, 85]
])
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
#Get the shape of the matrix.
#Find the average age of students.
#Extract Math marks of all students.
#Find the highest Science mark.

# %%
data.shape
# Out:
# (5, 3)

# %%
age = data[0:,:1]
age
# Out:
# array([[18],
#        [19],
#        [17],
#        [18],
#        [20]])

# %%
age.mean()
# Out:
# np.float64(18.4)

# %%
math_marks = data[0:,1:2]
math_marks
# Out:
# array([[85],
#        [92],
#        [76],
#        [65],
#        [90]])

# %%
science_marks = data[0:,2:].max()
science_marks
# Out:
# np.int64(95)

# %%
#Get details of the student who scored more than 90 in Math.
math_marks[math_marks > 90]
# Out:
# array([92])

# %%
#Increase Math marks of all students by 5.
new_math_marks = math_marks + 5
new_math_marks
# Out:
# array([[90],
#        [97],
#        [81],
#        [70],
#        [95]])

# %%
#Find how many students are younger than 19.
ages = data[0:,:1]
ages[ages<19]
# Out:
# array([18, 17, 18])

# %%
#Calculate the average marks in each subject (column-wise mean).


data[0:,1:].mean(axis =0)
np.mean(data[0:,1:],axis = 0) # Both are same
# Out:
# array([81.6, 83.2])

# %%
#Get data of students who scored at least 80 in both subjects.
data[(data[:,1]>=80) & (data[:,2] >=80)]
# Out:
# array([[19, 92, 88],
#        [20, 90, 85]])

# %%
#Replace all Science marks < 75 with 0.
data[0:,2:][data[0:,2:] < 75] = 0
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65,  0],
#        [20, 90, 85]])
