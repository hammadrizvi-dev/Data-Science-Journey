# %%
import pandas as pd

# %%
df = pd.read_csv(
    "D:/02_Courses_Learning/student-performance-analysis/data/student_performance.csv"
)

# %%
df.shape
# Out:
# (3, 6)

# %%
df.head()
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 0           1    Male          2.5          72              61           65
# 1           2  Female          5.0          91              78           84
# 2           3    Male          1.5          60              52           49

# %%
df.describe()
# Out:
#        student_id  study_hours  attendance  previous_marks  final_marks
# count         3.0     3.000000    3.000000        3.000000     3.000000
# mean          2.0     3.000000   74.333333       63.666667    66.000000
# std           1.0     1.802776   15.631165       13.203535    17.521415
# min           1.0     1.500000   60.000000       52.000000    49.000000
# 25%           1.5     2.000000   66.000000       56.500000    57.000000
# 50%           2.0     2.500000   72.000000       61.000000    65.000000
# 75%           2.5     3.750000   81.500000       69.500000    74.500000
# max           3.0     5.000000   91.000000       78.000000    84.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      3 non-null      int64
#  1   gender          3 non-null      object
#  2   study_hours     3 non-null      float64
#  3   attendance      3 non-null      int64
#  4   previous_marks  3 non-null      int64
#  5   final_marks     3 non-null      int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 276.0+ bytes

# %%
df["final_marks"].mean()
# Out:
# np.float64(66.0)

# %%
df["study_hours"].mean()
# Out:
# np.float64(3.0)

# %%
df["final_marks"].max()
# Out:
# 84

# %%
df["final_marks"].min()
# Out:
# 49

# %%
df["final_marks"].max()
# Out:
# 84

# %%
df[df["final_marks"] == df["final_marks"].max()]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 1           2  Female          5.0          91              78           84

# %%
df[df["final_marks"] > 60]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 0           1    Male          2.5          72              61           65
# 1           2  Female          5.0          91              78           84

# %%
df[df["attendance"] < 70]
# Out:
#    student_id gender  study_hours  attendance  previous_marks  final_marks
# 2           3   Male          1.5          60              52           49

# %%
df[df["gender"] == "Female"]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 1           2  Female          5.0          91              78           84

# %%
df[
    (df["study_hours"] >3 ) & (df["final_marks"] >70 )
    ]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 1           2  Female          5.0          91              78           84

# %%
df[
    (df["attendance"] > 70 ) | 
    (df["final_marks"] > 80 )
    ]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 0           1    Male          2.5          72              61           65
# 1           2  Female          5.0          91              78           84

# %%
df["study_hours"]
# Out:
# 0    2.5
# 1    5.0
# 2    1.5
# Name: study_hours, dtype: float64

# %%
df[["study_hours", "attendance"]]
# Out:
#    study_hours  attendance
# 0          2.5          72
# 1          5.0          91
# 2          1.5          60

# %%
df.loc[0, "final_marks"]
# Out:
# np.int64(65)

# %%
df.loc[0, ["study_hours", "attendance", "final_marks"]]
# Out:
# study_hours    2.5
# attendance      72
# final_marks     65
# Name: 0, dtype: object

# %%
df.loc[
    df["final_marks"] > 60,
    ["study_hours", "final_marks"]
]
# Out:
#    study_hours  final_marks
# 0          2.5           65
# 1          5.0           84

# %%
df.loc[
    df["attendance"] > 70,
    ["final_marks", "study_hours", "attendance"]
    ]
# Out:
#    final_marks  study_hours  attendance
# 0           65          2.5          72
# 1           84          5.0          91

# %%
df.iloc[:]
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 0           1    Male          2.5          72              61           65
# 1           2  Female          5.0          91              78           84
# 2           3    Male          1.5          60              52           49

# %%
df.iloc[1,4]
# Out:
# np.int64(78)

# %%
df.sort_values(by="final_marks", ascending=False)
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 1           2  Female          5.0          91              78           84
# 0           1    Male          2.5          72              61           65
# 2           3    Male          1.5          60              52           49

# %%
df.sort_values(
    by="final_marks",
    ascending=False
)[["student_id", "study_hours", "final_marks"]]
# Out:
#    student_id  study_hours  final_marks
# 1           2          5.0           84
# 0           1          2.5           65
# 2           3          1.5           49

# %%
df.loc[:,
    ("student_id", "attendance", "final_marks")
    ]
# Out:
#    student_id  attendance  final_marks
# 0           1          72           65
# 1           2          91           84
# 2           3          60           49

# %%
df.sort_values(by ="study_hours", ascending=False)
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 1           2  Female          5.0          91              78           84
# 0           1    Male          2.5          72              61           65
# 2           3    Male          1.5          60              52           49

# %%
df.sort_values(by ="final_marks", ascending=True)
# Out:
#    student_id  gender  study_hours  attendance  previous_marks  final_marks
# 2           3    Male          1.5          60              52           49
# 0           1    Male          2.5          72              61           65
# 1           2  Female          5.0          91              78           84

# %%
df.loc[2,
    ["study_hours","final_marks"]]
# Out:
# study_hours    1.5
# final_marks     49
# Name: 2, dtype: object

# %%
df.loc[
    df["final_marks"] >60 ,
    ["student_id", "study_hours", "final_marks"]
    ]
# Out:
#    student_id  study_hours  final_marks
# 0           1          2.5           65
# 1           2          5.0           84

# %%
df[["student_id", "attendance", "final_marks"]]
# Out:
#    student_id  attendance  final_marks
# 0           1          72           65
# 1           2          91           84
# 2           3          60           49

# %%
df.iloc[0]
# Out:
# student_id           1
# gender            Male
# study_hours        2.5
# attendance          72
# previous_marks      61
# final_marks         65
# Name: 0, dtype: object

# %%
df.iloc[1, 5]
# Out:
# np.int64(84)

# %%
df.loc[1, "final_marks"]
# Out:
# np.int64(84)

# %%
df_sorted = df.sort_values(by="final_marks", ascending=False)

# %%
df_sorted.iloc[0]
# Out:
# student_id             2
# gender            Female
# study_hours          5.0
# attendance            91
# previous_marks        78
# final_marks           84
# Name: 1, dtype: object

# %%
df_sorted.loc[0]
# Out:
# student_id           1
# gender            Male
# study_hours        2.5
# attendance          72
# previous_marks      61
# final_marks         65
# Name: 0, dtype: object

# %%
df_sorted.iloc[0]
# Out:
# student_id             2
# gender            Female
# study_hours          5.0
# attendance            91
# previous_marks        78
# final_marks           84
# Name: 1, dtype: object
