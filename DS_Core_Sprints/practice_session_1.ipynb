# %% [markdown]
# <a href="https://colab.research.google.com/github/hammadrizvi-dev/Data-Science-Journey/blob/main/DS_Core_Sprints/practice_session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
